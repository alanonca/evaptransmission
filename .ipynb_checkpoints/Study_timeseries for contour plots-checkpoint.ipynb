# %%
from numpy import savetxt
import numpy as np
import csv

# %%
with open('20201008_King_April_output.csv') as output_file:
    metadata = csv.reader(output_file, delimiter=',')
    extractdata = []
    for item in metadata:
        extractdata.append(item)
tsetdata = np.asfarray(extractdata[0],float) 
viabdata = np.asfarray(extractdata[1],float) 

tset = []
viab_hl = []
tset_span = np.linspace(min(tsetdata), max(tsetdata),20, endpoint=True)
viab_span = np.linspace(min(viabdata),max(viabdata),20, endpoint=True) 
for i in range(len(tset_span)):
    ts = tset_span[i]
    for j in range(len(viab_span)):
        vi = viab_span[j]
        tset.append(ts)
        viab_hl.append(vi)
        
outputdata = [tset,viab_hl]
savetxt('20201008_contourdata_King.csv', outputdata, delimiter=',')

# %%
# Out:
# [20.841548252145316, 23.3927677155058, 25.943987178866287, 28.49520664222677, 31.04642610558726, 33.59764556894774, 36.14886503230822, 38.70008449566871, 41.2513039590292, 43.80252342238968, 46.353742885750165, 48.904962349110654, 51.45618181247114, 54.007401275831626, 56.55862073919211, 59.1098402025526, 61.66105966591308, 64.21227912927355, 66.76349859263405, 69.31471805599453, 20.841548252145316, 23.3927677155058, 25.943987178866287, 28.49520664222677, 31.04642610558726, 33.59764556894774, 36.14886503230822, 38.70008449566871, 41.2513039590292, 43.80252342238968, 46.353742885750165, 48.904962349110654, 51.45618181247114, 54.007401275831626, 56.55862073919211, 59.1098402025526, 61.66105966591308, 64.21227912927355, 66.76349859263405, 69.31471805599453, 20.841548252145316, 23.3927677155058, 25.943987178866287, 28.49520664222677, 31.04642610558726, 33.59764556894774, 36.14886503230822, 38.70008449566871, 41.2513039590292, 43.80252342238968, 46.353742885750165, 48.904962349110654, 51.
# ...
